# %%
import pandas as pd

# %%
Dfcredit = pd.read_csv('default of credit card clients.csv', header =1)
Dfcredit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default_payment_next_month
# ...

# %%
Dfcredit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
Dfcredit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %%
# Dfcredit = pd.DataFrame(credit)
# Dfcredit

# %%
pd.isnull(Dfcredit).sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default_payment_next_month    0
# dtype: int64

# %%
pd.notnull(Dfcredit).sum()
# Out:
# ID                            30000
# LIMIT_BAL                     30000
# SEX                           30000
# EDUCATION                     30000
# MARRIAGE                      30000
# AGE                           30000
# PAY_0                         30000
# PAY_2                         30000
# PAY_3                         30000
# PAY_4                         30000
# PAY_5                         30000
# PAY_6                         30000
# BILL_AMT1                     30000
# BILL_AMT2                     30000
# BILL_AMT3                     30000
# BILL_AMT4                     30000
# BILL_AMT5                     30000
# BILL_AMT6                     30000
# PAY_AMT1                      30000
# PAY_AMT2                      30000
# PAY_AMT3                      30000
# PAY_AMT4                      30000
# PAY_AMT5                      30000
# PAY_AMT6                      30000
# default_payment_next_month    30000
# dtype: int64

# %%
Dfcredit.drop_duplicates()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
header = Dfcredit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default_payment_next_month'],
#       dtype='object')

# %%
plt.hist(Dfcredit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(Dfcredit['SEX'])
plt.show()

# %%
plt.hist(Dfcredit['MARRIAGE'])
plt.show()

# %%
plt.hist(Dfcredit['AGE'])
plt.show()

# %%
plt.hist(Dfcredit['EDUCATION'])
plt.show()

# %%
plt.hist(Dfcredit['default_payment_next_month'])
plt.show()

# %%
plt.hist(Dfcredit['default_payment_next_month'], bins=4)
# Out:
# (array([23364.,     0.,     0.,  6636.]),
#  array([0.  , 0.25, 0.5 , 0.75, 1.  ]),
#  <BarContainer object of 4 artists>)

# %%
Dfcredit.SEX.describe()
# Out:
# count    30000.000000
# mean         1.603733
# std          0.489129
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000
# Name: SEX, dtype: float64

# %%
Dfcredit.EDUCATION.describe()
# Out:
# count    30000.000000
# mean         1.853133
# std          0.790349
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          6.000000
# Name: EDUCATION, dtype: float64

# %%
Dfcredit.MARRIAGE.describe()
# Out:
# count    30000.000000
# mean         1.551867
# std          0.521970
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          3.000000
# Name: MARRIAGE, dtype: float64

# %%
Dfcredit.LIMIT_BAL.describe()
# Out:
# count      30000.000000
# mean      167484.322667
# std       129747.661567
# min        10000.000000
# 25%        50000.000000
# 50%       140000.000000
# 75%       240000.000000
# max      1000000.000000
# Name: LIMIT_BAL, dtype: float64

# %%
Dfcredit.default_payment_next_month.describe()
# Out:
# count    30000.000000
# mean         0.221200
# std          0.415062
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: default_payment_next_month, dtype: float64

# %%
Dfcredit["SEX"] = Dfcredit["SEX"].astype("category")
Dfcredit["EDUCATION"] = Dfcredit["EDUCATION"].astype("category")
Dfcredit["MARRIAGE"] = Dfcredit["MARRIAGE"].astype("category")
Dfcredit["default_payment_next_month"] = Dfcredit["default_payment_next_month"].astype("category")

# %%
Dfcredit.describe()
# Out:
#                  ID       LIMIT_BAL           AGE         PAY_0         PAY_2  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667     35.485500     -0.016700     -0.133767
# std     8660.398374   129747.661567      9.217904      1.123802      1.197186
# min        1.000000    10000.000000     21.000000     -2.000000     -2.000000
# 25%     7500.750000    50000.000000     28.000000     -1.000000     -1.000000
# 50%    15000.500000   140000.000000     34.000000      0.000000      0.000000
# 75%    22500.250000   240000.000000     41.000000      0.000000      0.000000
# max    30000.000000  1000000.000000     79.000000      8.000000      8.000000
#
#               PAY_3         PAY_4         PAY_5         PAY_6      BILL_AMT1  \
# count  30000.000000  30000.000000  30000.000000  30000.000000   30000.000000
# mean      -0.166200     -0.220667     -0.266200     -0.291100   51223.330900
# ...

# %%
#Dfcredit["LIMIT_BAL"] = Dfcredit["LIMIT_BAL"].astype("category")

# %%
plt.plot(Dfcredit['LIMIT_BAL'])
plt.show()

# %%
x = Dfcredit['PAY_0']
y = Dfcredit['PAY_2']

# %%
plt.scatter(x,y)
plt.show()

# %%
x = Dfcredit['LIMIT_BAL']
y = Dfcredit['AGE']

# %%
plt.scatter(x,y)
plt.show()

# %%
header = Dfcredit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default_payment_next_month'],
#       dtype='object')

# %%
A = Dfcredit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
corrMat = Dfcredit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
covMat = Dfcredit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...
